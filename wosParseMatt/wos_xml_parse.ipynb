# %%
from pyspark.sql import SparkSession, SQLContext
from pyspark import SparkConf, SparkContext
from pyspark.sql.types import *
from pyspark.sql.functions import col, explode, concat_ws, collect_list, sort_array, count, size, coalesce, expr
spark= SparkSession.builder.config('spark.ui.port','4040').getOrCreate()

# %%
spark.conf.set('spark.sql.caseSensitive', 'True')

# %%
WoS = spark.read.format("parquet").load("/WoSraw_2020_all/parquet/part-00826-5476e87f-146e-4916-913b-522638c0d728-c000.snappy.parquet")

# %%
#wosOa = WoS.select(WoS.UID.alias("wosID"),
#                   WoS.dynamic_data.ic_related.oases['_is_OA'].alias('isOpenAccess'),
#                   concat_ws(", ", WoS.dynamic_data.ic_related.oases.oas['_type']).alias('openAccessType'),
#                  )
#wos0a

#wosOa.show(50, truncate = False)

# %%
#WoS.printSchema()

# %%
wos4a = WoS.select(WoS.UID.alias("wosID"),
                  WoS.dynamic_data.ic_related.oases['_is_OA'].alias('isOpenAccess'),
                  concat_ws(", ", WoS.dynamic_data.ic_related.oases.oas['_type']).alias('openAccessType'), 
                  WoS.static_data.fullrecord_metadata.abstracts.abstract.abstract_text.p[0].alias("abstract"),
                  WoS.static_data.fullrecord_metadata.fund_ack.fund_text.p.alias("fundingText"),
                  WoS.static_data.fullrecord_metadata.references._count.alias("citedReferenceCount"),
                  WoS.static_data.fullrecord_metadata.addresses.address_name.address_spec['full_address'].alias('full_address'),
                  WoS.static_data.fullrecord_metadata.reprint_addresses.address_name.address_spec.full_address[0].alias('reprintAddress'),
                  WoS.static_data.fullrecord_metadata.references.reference.art_no.alias('articleNumber'),
                  WoS.static_data.summary.pub_info._pubyear.alias("publicationYear"),
                  WoS.static_data.summary.pub_info._coverdate.alias("publicationDate"),
                  WoS.static_data.summary.pub_info._vol.alias("volume"),
                  WoS.static_data.summary.pub_info._issue.alias("issue"),
                  WoS.static_data.summary.pub_info._part_no.alias("partNumber"),
                  WoS.static_data.summary.pub_info._supplement.alias("supplement"),
                  WoS.static_data.summary.pub_info._special_issue.alias("specialIssue"),
                  WoS.static_data.summary.pub_info._early_access_date.alias("earlyAccessDate"),
                  WoS.static_data.summary.pub_info.page._begin.alias("startPage"),
                  WoS.static_data.summary.pub_info.page._end.alias("endPage"),
                  WoS.static_data.summary.pub_info.page._page_count.alias("numberOfPages"),
                  WoS.static_data.summary.publishers.publisher.address_spec.city.alias("publisherCity"),
                  WoS.static_data.summary.publishers.publisher.address_spec.full_address.alias("publisherAddress"),
                  WoS.static_data.summary.publishers.publisher.names["name"]["full_name"].alias('publisher'),
                  WoS.static_data.item.keywords_plus.keyword.alias('keywordsPlus'),
                  WoS.static_data.summary.conferences.conference.conf_dates.conf_date._VALUE.alias("conferenceDate"),
                  WoS.static_data.summary.conferences.conference.sponsors.sponsor[0].alias("conferenceSponsor"),
                  WoS.static_data.summary.conferences.conference.conf_locations.conf_location.conf_host.alias("conferenceHost"),
                  WoS.static_data.summary.conferences.conference.conf_titles.conf_title[0].alias("conferenceTitle"),
                  WoS.static_data.summary.doctypes.doctype[0].alias('documentType')
                 )
#wos4.printSchema()

wos4 = wos4a.withColumn("fundingText",        concat_ws(", ",  col("fundingText")))       \
            .withColumn("full_address",       concat_ws(", ",  col("full_address")))      \
            .withColumn("articleNumber",      concat_ws(", ",  col("articleNumber")))     \
            .withColumn("keywordsPlus",       concat_ws(", ",  col("keywordsPlus")))      \
            .withColumn("conferenceDate",     concat_ws(", ",  col("conferenceDate")))    \
            .withColumn("conferenceSponsor",  concat_ws(", ",  col("conferenceSponsor"))) \
            .withColumn("conferenceHost",     concat_ws(", ",  col("conferenceHost"))) 
                         
                    
#wos4.printSchema()

# %%
#BUILD AUTHOR ARRAY
wos5 = WoS.select(WoS.UID.alias("wosID"), WoS.static_data.contributors.contributor.alias("author"))

wos6 = wos5.withColumn("author", explode("author")).select("*", col("author")["name"]["_seq_no"].alias("seq_no"),
                                                                col("author")["name"]["full_name"].alias("fullname"),
                                                                col("author")["name"]["_r_id"].alias("RIDs"), 
                                                                col("author")["name"]["_orcid_id"].alias("ORCID"),
                                                                col("author")["name"]["display_name"].alias("standardNames")    
                                                          )

wos_author = wos6.select("wosID", concat_ws(" ", wos6.fullname,      wos6.seq_no).alias("author"), 
                                  concat_ws(" ", wos6.RIDs,          wos6.seq_no).alias("RIDs"), 
                                  concat_ws(" ", wos6.ORCID,         wos6.seq_no).alias("ORCID"),
                                  concat_ws(" ", wos6.standardNames, wos6.seq_no).alias("standardNames")
                        )


wos_auth2 = wos_author.groupBy("wosID").agg(sort_array(collect_list("author")).alias("authors"),
                                            sort_array(collect_list("RIDs")).alias("RIDs"),
                                            sort_array(collect_list("ORCID")).alias("ORCID"),
                                            sort_array(collect_list("standardNames")).alias("standardNames")
                                           )  
                                            

wos_auth2 = wos_auth2.select(
   col('wosID'),
   concat_ws("| ", col('RIDs')).alias('RIDs'),
   concat_ws("| ", col('ORCID')).alias('ORCID'),
   concat_ws("| ", col('standardNames')).alias('standardNames'),  
   concat_ws("| ",col('authors')).alias('authors'), 
   size('authors').alias('count')
)

wos_auth2 = wos_auth2.drop('count')

#wos_auth2.show(4, truncate=True)

# %%
#EMAIL ADDRESSES
wosEmail = WoS.select(WoS.UID.alias("wosID"), WoS.static_data.fullrecord_metadata.addresses.address_name.names.alias("addr"))

wosEmail2 = wosEmail.withColumn("addr", explode("addr")).select("*",
                                                                col("addr")["name"]["_seq_no"].alias("seq_no"),
                                                                col("addr")["name"]["email_addr"].alias("emailAddress"),
                                                          )

wosEmail3 = wosEmail2.select("wosID",
                                  concat_ws(" ", wosEmail2.emailAddress,  wosEmail2.seq_no).alias("emailAddress")
                        )


wosEmail4 = wosEmail3.groupBy("wosID").agg(
                                            sort_array(collect_list("emailAddress")).alias("emailAddress")
                                           )  
                                            

wosEmail5 = wosEmail4.select(
   col('wosID'),
   concat_ws("| ", col('emailAddress')).alias('emailAddress'), 
   size('emailAddress').alias('count')
)

wosEmail5 = wosEmail5.drop('count')

#wosEmail5.show(4, truncate=True)
#wos5.show(10, truncate=False)

# %%
#BUILD TITLE COLUMNS

wos_title = WoS.select(WoS.UID.alias("wosID"),
                      WoS.static_data.summary.titles.title.alias('title'))

wosTitle2 = wos_title.withColumn("title", explode("title")).select("*", col("title")["_type"].alias("paperTitle"))


wosTitle3 = wosTitle2.select('wosID', 'title.*')
                                       
item   = wosTitle3.filter(wosTitle3._type == "item")
item   = item.select('wosID', col('_VALUE').alias('paperTitle'))

source = wosTitle3.filter(wosTitle3._type == "source")
source = source.select(col('wosID').alias('id2'), col('_VALUE').alias('journalTitle'))

journalAbbr = wosTitle3.filter(wosTitle3._type == "source_abbrev")
journalAbbr = journalAbbr.select(col('wosID').alias('id3'), col('_VALUE').alias('journalAbbrev'))

journalISO = wosTitle3.filter(wosTitle3._type == "abbrev_iso")
journalISO = journalISO.select(col('wosID').alias('id4'), col('_VALUE').alias('journalISO'))

wosTitle4 = item.join(source,      item['wosID'] == source['id2'], how='full') \
                .join(journalAbbr, item['wosID'] == journalAbbr['id3'], how='full') \
                .join(journalISO,  item['wosID'] == journalISO['id4'], how='full') \
                .select(coalesce(item.wosID, source.id2, journalAbbr.id3, journalISO.id4).alias('wosID'), 
                        item.paperTitle, 
                        source.journalTitle,
                        journalAbbr.journalAbbrev, 
                        journalISO.journalISO)

#wosTitle4 = wosTitle4.drop('id2', 'id3', 'id4')

#wosTitle4.show(10, truncate = True)

# %%
#BUILD ISSN/EISSN/DOI TABLE

wosIdPlus = WoS.select(WoS.UID.alias("wosID"),
                       WoS.dynamic_data.cluster_related.identifiers.identifier.alias('ids'))

wosIdPlus2 = wosIdPlus.withColumn("ids", explode("ids")).select("*", col("ids")["_type"].alias("altID"))

wosIdPlus3 = wosIdPlus2.select('wosID', 'ids.*')

issn   = wosIdPlus3.filter(wosIdPlus3._type == "issn")
issn   = issn.select('wosID', col('_value').alias('issn'))

doi   = wosIdPlus3.filter(wosIdPlus3._type == "doi")
doi   = doi.select(col('wosID').alias('id2'), col('_value').alias('doi'))

eissn   = wosIdPlus3.filter(wosIdPlus3._type == "eissn")
eissn   = eissn.select(col('wosID').alias('id3'), col('_value').alias('eissn'))

isbn   = wosIdPlus3.filter(wosIdPlus3._type == "isbn")
isbn   = isbn.select(col('wosID').alias('id4'), col('_value').alias('isbn'))

pmid   = wosIdPlus3.filter(wosIdPlus3._type == "pmid")
pmid   = pmid.select(col('wosID').alias('id5'), col('_value').alias('pmid'))

wosIdPlus4 = issn.join(doi,   issn['wosID'] == doi['id2'],  how='full') \
                 .join(eissn, issn['wosID'] == eissn['id3'],how='full') \
                 .join(isbn,  issn['wosID'] == isbn['id4'], how='full') \
                 .join(pmid,  issn['wosID'] == pmid['id5'], how='full') \
                 .select(coalesce(issn.wosID, doi.id2, eissn.id3, isbn.id4, pmid.id5).alias('wosID'), 
                         issn.issn, doi.doi, eissn.eissn, isbn.isbn, pmid.pmid)


#wosIdPlus4.show(10, truncate = False)

# %%
#BUILD CONFERENCE LOCATION

wosCoLo = WoS.select(WoS.UID.alias("wosID"),
                    WoS.static_data.summary.conferences.conference.conf_locations.conf_location.conf_city.alias("conf_city"),
                    WoS.static_data.summary.conferences.conference.conf_locations.conf_location.conf_host.alias("conf_host"),
                    WoS.static_data.summary.conferences.conference.conf_locations.conf_location.conf_state.alias("conf_state")
                    )

wosCoLo2 = wosCoLo.withColumn('conferenceLocation', concat_ws(", ", wosCoLo.conf_city, wosCoLo.conf_host, wosCoLo.conf_state))

#wosCoLo2.show(10)
wosCoLo2 = wosCoLo2.drop('conf_city')
wosCoLo2 = wosCoLo2.drop('conf_host')
wosCoLo2 = wosCoLo2.drop('conf_state')

#wosCoLo2.printSchema()

# %%
#BUILD FUNDING ORG String

wosFo = WoS.select(WoS.UID.alias("wosID"),
                WoS.static_data.fullrecord_metadata.fund_ack.grants.grant.grant_agency[0].alias('fundingOrgs'))


wosFo2 = wosFo.withColumn("fundingOrgs", col("fundingOrgs").getField("_VALUE"))

wosFo3 = wosFo2.withColumn("fundingOrgs", concat_ws("| ", wosFo2.fundingOrgs))


#wosFo3.show(10, truncate = False)

# %%
wosOutput = wos4.join(wos_auth2,  wos4['wosID'] == wos_auth2['wosID'], how='full') \
                .join(wosEmail5,  wos4['wosID'] == wosEmail5['wosID'], how='full') \
                .join(wosTitle4,  wos4['wosID'] == wosTitle4['wosID'], how='full') \
                .join(wosIdPlus4, wos4['wosID'] == wosIdPlus4['wosID'],how='full') \
                .join(wosCoLo2,   wos4['wosID'] == wosCoLo2['wosID'],  how='full') \
                .join(wosFo3,     wos4['wosID'] == wosFo3['wosID'],    how='full') \
                .select(coalesce(wos4.wosID, 
                                 wos_auth2.wosID, 
                                 wosEmail5.wosID, 
                                 wosTitle4.wosID, 
                                 wosIdPlus4.wosID,
                                 wosCoLo2.wosID,
                                 wosFo3.wosID).alias('wosID'),
                  wos4.abstract,
                  wos4.fundingText,        
                  wos4.citedReferenceCount,      
                  wos4.full_address,     
                  wos4.reprintAddress,   
                  wos4.articleNumber,
                  wos4.publicationYear,
                  wos4.publicationDate,
                  wos4.volume,
                  wos4.issue,
                  wos4.partNumber,
                  wos4.supplement,
                  wos4.specialIssue,
                  wos4.earlyAccessDate,
                  wos4.startPage,
                  wos4.endPage,
                  wos4.numberOfPages,
                  wos4.publisherCity,
                  wos4.publisherAddress,
                  wos4.publisher,
                  wos4.keywordsPlus,
                  wos4.conferenceDate,
                  wos4.conferenceSponsor,
                  wos4.conferenceHost,
                  wos4.conferenceTitle,
                  wos4.documentType,
                      wos_auth2.RIDs,
                      wos_auth2.ORCID,
                      wos_auth2.standardNames,
                      wos_auth2.authors,
                        wosEmail5.emailAddress,
                            wosTitle4.paperTitle, 
                            wosTitle4.journalTitle,
                            wosTitle4.journalAbbrev, 
                            wosTitle4.journalISO,
                                wosIdPlus4.issn,
                                wosIdPlus4.doi,
                                wosIdPlus4.eissn, 
                                wosIdPlus4.isbn,
                                wosIdPlus4.pmid,
                                    wosCoLo2.conferenceLocation,
                                        wosFo3.fundingOrgs
                       )
                        
            


#wosOutput.printSchema()

wosOutput.show(25)
# Out:
# +-------------------+--------------------+--------------------+-------------------+--------------------+--------------------+-------------+---------------+---------------+------+-----+----------+----------+------------+---------------+---------+-------+-------------+---------------+--------------------+--------------------+--------------------+--------------+-----------------+--------------+---------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+---------+----+--------+------------------+--------------------+
# |              wosID|            abstract|         fundingText|citedReferenceCount|        full_address|      reprintAddress|articleNumber|publicationYear|publicationDate|volume|issue|partNumber|supplement|specialIssue|earlyAccessDate|startPage|endPage|numberOfPages|  publisherCity|    publisherAddress|           publisher|        keywordsPlus|conferenceDate|conferenceSponsor|conferenceHost|conferenceTitle|      documentType|                RIDs|               ORCID|       standardNames|             authors|        emailAddress|          paperTitle|        journalTitle|       journalAbbrev|          journalISO|     issn|                 doi|    eissn|isbn|    pmid|conferenceLocation|         fundingOrgs|
# +-------------------+--------------------+--------------------+-------------------+--------------------+--------------------+-------------+---------------+---------------+------+-----+----------+----------+------------+---------------+---------+-------+-------------+---------------+--------------------+--------------------+--------------------+--------------+-----------------+--------------+---------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+---------+----+--------+------------------+--------------------+
# |WOS:000577436500001|Objective: to des...|                    |                 55|Univ Coimbra, Coi...|Univ Metropolitan...|             |           2021|           2021|  null|   39|      null|      null|        null|           null|      547|    555|            9|         MURCIA|C CABO VIDIO 27, ...|FEDERACION ESPANO...|INTERMITTENT RECO...|              |                 |              |           null|           Article|       K-8684-2012 1|0000-0001-8681-06...|    Sarmento, Hugo 1|    Sarmento, Hugo 1|1 4| 2| maureiraf...|Analysis of the p...|RETOS-NUEVAS TEND...|RETOS-NUEV TEND EDUC|               Retos|1579-1726|                null|1988-2041|null|    null|                  |                    |
# |WOS:000582231600001|From the theoreti...|                    |                 18|Univ Fed Paraiba,...|Univ Fed Paraiba,...|             |           2021|   JAN-APR 2021|     6|    1|      null|      null|        null|           null|     null|   null|           19|FORTALEZA-CEARA|AV DOUTOR SILAS M...|STATE UNIV CEARA,...|                    |              |                 |              |           null|           Article|                   1|0000-0002-4768-87...|Jose dos Santos M...|Jose dos Santos M...|charlitonlara@yah...|"Teaching childre...| EDUCACAO & FORMACAO|       EDUC FORMACAO|      Educ. Formacao|     null|                null|2448-3583|null|    null|                  |                    |
# |WOS:000582231600001|From the theoreti...|                    |                 18|Univ Fed Paraiba,...|Univ Fed Paraiba,...|             |           2021|   JAN-APR 2021|     6|    1|      null|      null|        null|           null|     null|   null|           19|FORTALEZA-CEARA|AV DOUTOR SILAS M...|STATE UNIV CEARA,...|                    |              |                 |              |           null|           Article|                   1|0000-0002-4768-87...|Jose dos Santos M...|Jose dos Santos M...|charlitonlara@yah...|"Teaching childre...| EDUCACAO & FORMACAO|       EDUC FORMACAO|      Educ. Formacao|     null|10.25053/redufor....|     null|null|    null|                  |                    |
# |WOS:000582346400001|The practice of s...|                    |                 27|Inst Politecn Cas...|Inst Politecn Cas...|             |           2021|           2021|  null|   39|      null|      null|        null|           null|      998|   1000|            3|         MURCIA|C CABO VIDIO 27, ...|FEDERACION ESPANO...|VALIDATION, MOTIV...|              |                 |              |           null|           Article|                null|                null|                null|                null|marco.batista@ipc...|Lifestyles and sa...|RETOS-NUEVAS TEND...|RETOS-NUEV TEND EDUC|               Retos|1579-1726|                null|1988-2041|null|    null|                  |                    |
# |WOS:000583881400007|This paper propos...|                    |                144|Univ Bergamo, Dep...|Univ Bergamo, Dep...|             |           2021|       FEB 2021|     6|    1|      null|      null|        null|           null|       79|    102|           24|       DEHRADUN|INT JOURNAL MATHE...|INT JOURNAL MATHE...|SYSTEM FAILURE BE...|              |                 |              |           null|           Article|                null|                null|                null|                null|christian.spreafi...|A Semi-Automatic ...|INTERNATIONAL JOU...|INT J MATH ENG MANAG|Int. J. Math. Eng...|2455-7749|10.33889/IJMEMS.2...|     null|null|    null|                  |                    |
# |WOS:000591838600007|Currently, the te...|                    |                 39|Univ Santiago Com...|Univ Santiago Com...|             |           2021|       JAN 2021|    24|    1|      null|      null|        null|           null|      137|    157|           21|         MADRID|UNED, FAC EDUC, C...|ASOC IBEROAMERICA...|INNOVATION, RESOU...|              |                 |              |           null|           Article|                null|                null|                null|                null|beatriz.cebreiro@...|New digital skill...|RIED-REVISTA IBER...|RIED-REV IBEROAM EDU|RIED-Rev. Iberoam...|1138-2783|10.5944/ried.24.1...|1390-3306|null|    null|                  |                    |
# |WOS:000593866600001|The effects of th...|This study was su...|                 30|Food Sci & Nutr D...|Food Sci & Nutr D...|             |           2021|       APR 2021|     6|    1|      null|      null|        null|           null|     null|   null|            7|     HEIDELBERG|TIERGARTENSTRASSE...| SPRINGER HEIDELBERG|PHYSICOCHEMICAL C...|              |                 |              |           null|           Article|                null|                null|                null|                null|5| 5| t.ouchbani@...|Effects of the he...|EURO-MEDITERRANEA...|EURO-MEDITERR J ENVI|Euro-Mediterr. J....|2365-6433|10.1007/s41207-02...|2365-7448|null|    null|                  |SATREPS (Science ...|
# |WOS:000596913200013|The investigation...|                    |                 12|Farook Coll, Dept...|Farook Coll, Dept...|             |           2021|           2021|    11| null|      null|      null|          SI|           null|      124|    132|            9|           BAKU|Z KHALILOV STR, 2...|TURKIC WORLD MATH...|                    |              |                 |              |           null|           Article|                null|                null|                null|                null|jicychanth@gmail....|OPERATIONS ON TOT...|TWMS JOURNAL OF A...|TWMS J APPL ENG MATH|TWMS J. Appl. Eng...|2146-1147|                null|     null|null|    null|                  |                    |
# |WOS:000597141300007|When solving a qu...|This work was sup...|                 18|Linkoping Univ, D...|Linkoping Univ, D...|             |           2021|       OCT 2021|     5|    4|      null|      null|        null|           null|     1381|   1386|            6|     PISCATAWAY|445 HOES LANE, PI...|IEEE-INST ELECTRI...|                    |              |                 |              |           null|           Article|                   1|0000-0001-6761-08...| Bemporad, Alberto 1| Bemporad, Alberto 1|alberto.bemporad@...|Complexity Certif...|IEEE CONTROL SYST...|IEEE CONTR SYST LETT|IEEE Control Syst...|2475-1456|10.1109/LCSYS.202...|     null|null|    null|                  |Swedish Research ...|
# |WOS:000543958500011|Symbolic models h...|This work was sup...|                 40|Tech Univ Munich,...|Tech Univ Munich,...|             |           2021|      JAN. 2021|     5|    1|      null|      null|        null|           null|      247|    252|            6|     PISCATAWAY|445 HOES LANE, PI...|IEEE-INST ELECTRI...|TO-STATE STABILIT...|              |                 |              |           null|           Article|                null|                null|                null|                null|abdalla.swikir@tu...|Symbolic Models f...|IEEE CONTROL SYST...|IEEE CONTR SYST LETT|IEEE Control Syst...|2475-1456|10.1109/LCSYS.202...|     null|null|    null|                  |H2020 ERC Startin...|
# |WOS:000575223400008|Introduction: Acu...|The author would ...|                 22|Urmia Univ Med Sc...|Urmia Univ Med Sc...|             |           2021|       JAN 2021|     7|    1|      null|      null|        null|           null|     null|   null|            5|        ISFAHAN|NO 8, 23 LN, FARA...| NIKAN RESEARCH INST|  MULTIPLE-SCLEROSIS|              |                 |              |           null|           Article|                null|                null|                null|                null|1| 4| Ezatolahaba...|Evaluation of dem...|IMMUNOPATHOLOGIA ...|  IMMUNOPATHOL PERSA|Immiunopathol. Persa|2423-8015|10.34172/ipp.2021.08|     null|null|    null|                  |Urmia University ...|
# |WOS:000587503700003|In the present wo...|The authors ackno...|                 28|Narula Inst Techn...|Narula Inst Techn...|             |           2021|   JAN-MAR 2021|    11|    1|      null|      null|        null|           null|       34|     49|           16|        HERSHEY|701 E CHOCOLATE A...|          IGI GLOBAL|           VIBRATION|              |                 |              |           null|           Article|                null|                null|                null|                null|             1| 2| 3|Evaluation and Re...|INTERNATIONAL JOU...|INT J MANUF MATER ME|Int. J. Manuf. Ma...|2156-1680|10.4018/IJMMME.20...|2156-1672|null|    null|                  |RUSA 2.0 program ...|
# |WOS:000591598700039|The study concern...|Financial support...|                 15|AGH Univ Sci & Te...|AGH Univ Sci & Te...|             |           2021|       JAN 2021|    60|  1-2|      null|      null|        null|           null|       71|     74|            4|         ZAGREB|BERISLAVICEVA 6, ...|CROATIAN METALLUR...|         STEELS, HOT|              |                 |              |           null|           Article|                null|                null|                null|                null|pskubisz@metal.ag...|RESULTS OF THERMO...|         METALURGIJA|         METALURGIJA|         Metalurgija|0543-5846|                null|1334-2576|null|    null|                  |   MNiSzW within agr|
# |WOS:000596884600001|                null|                    |                 39|Prince Songkla Un...|Prince Songkla Un...|             |           2021|   JAN-MAR 2021|    25|    1|      null|      null|        null|           null|        1|      6|            6|     NONTHABURI|NAGARINDRASRI BLD...|THAILAND NURSING ...|CASE-STUDY METHOD...|              |                 |              |           null|Editorial Material|                null|                null|                null|                null|1| t.kurniawan198...|The Quest in Case...|PACIFIC RIM INTER...|PAC RIM INT J NURS R|Pac. Rim Int. J. ...|1906-8107|                null|     null|null|    null|                  |                    |
# |WOS:000557010000005|In this paper, we...|Authors would lik...|                  5|Huzhou Univ, Dept...|Govt Coll Univ, A...|             |           2021|           2021|    22|    2|      null|      null|        null|           null|      131|    141|           11|     MAZANDARAN|JOURNAL MATHEMATI...|JOURNAL MATHEMATI...|                    |              |                 |              |           null|           Article|       A-8803-2008 1|0000-0001-9320-94...| de la Sen, manuel 1| de la Sen, manuel 1|1| 3| 4| iabbasba...|The Jensen's ineq...|JOURNAL OF MATHEM...|J MATH COMPUT SCI-JM|J. Math. Comput. ...|2008-949X|10.22436/jmcs.022...|     null|null|    null|                  |Basque Government...|
# |WOS:000570975300037|Vitamin C is an e...|                    |                 29|Centurion Univ Te...|Centurion Univ Te...|             |           2021|    APR 15 2021|    11|    2|      null|      null|        null|           null|     9044|   9050|            7|      BUCURESTI|BIOINTERFACE RESE...|BIOINTERFACE RESE...|SURVIVAL, DISEASE...|              |                 |              |           null|           Article|     ABE-3342-2020 1|                   1|Parida, Siba pras...|Parida, Siba pras...|paridasp@gmail.co...|Vitamin-C Treated...|BIOINTERFACE RESE...|BIOINTERFACE RES APP|Biointerface Res....|2069-5837|10.33263/BRIAC112...|     null|null|    null|                  |                    |
# |WOS:000577179000001|Karate consists o...|                    |                 42|Univ Zaragoza, Za...|Univ Zaragoza, Za...|             |           2021|           2021|  null|   39|      null|      null|        null|           null|      367|    371|            5|         MURCIA|C CABO VIDIO 27, ...|FEDERACION ESPANO...|PERFORMANCE, TEST...|              |                 |              |           null|           Article|     ABE-6671-2020 1|0000-0002-6829-07...|de la Fuente, Fra...|de la Fuente, Fra...|dfalcon@unizar.es...|Unilateral and bi...|RETOS-NUEVAS TEND...|RETOS-NUEV TEND EDUC|               Retos|1579-1726|                null|1988-2041|null|    null|                  |                    |
# |WOS:000592803000009|                null|                    |                  3|Univ Colima, Coli...|Univ Colima, Coli...|             |           2021|   JAN-APR 2021|    56|    1|      null|      null|        null|           null|      193|    199|            7|    MEXICO CITY|DIR PABLO YANKELE...|COLEGIO DE MEXICO...|                    |              |                 |              |           null|       Book Review|                null|                null|                null|                null|  fhna@outlook.com 1|Wuhan Diary. Disp...|ESTUDIOS DE ASIA ...|      ESTUD ASIA AFR|    Estud. Asia Afr.|0185-0164|10.24201/eaa.v56i...|2448-654X|null|    null|                  |                    |
# |WOS:000593137200002|Spitzoid lesions ...|                    |                 34|Biskra Univ, LINF...|Biskra Univ, LINF...|             |           2021|   JAN-MAR 2021|    16|    1|      null|      null|        null|           null|       16|     37|           22|        HERSHEY|701 E CHOCOLATE A...|          IGI GLOBAL|IMBALANCED DATA, ...|              |                 |              |           null|           Article|                null|                null|                null|                null|        1 2| 3| 3| 4|Computer-Aided Di...|INTERNATIONAL JOU...|INT J HEALTHC INF SY|Int. J. Healthc. ...|1555-3396|10.4018/UHISI.202...|1555-340X|null|    null|                  |                    |
# |WOS:000595174400009|                null|                    |                  0|South Texas Hlth ...|SA Squared Tennes...|             |           2021|   JAN-FEB 2021|    26|    1|      null|      null|        null|           null|       36|     37|            2|   PHILADELPHIA|TWO COMMERCE SQ, ...|LIPPINCOTT WILLIA...|                    |              |                 |              |           null|Editorial Material|                null|                null|                null|                null|sherry@sa2com.com...|Aging Case Manage...|PROFESSIONAL CASE...|     PROF CASE MANAG|   Prof. Case Manag.|1932-8087|10.1097/NCM.00000...|1932-8095|null|33214511|                  |                    |
# |WOS:000596292800006|Organisational po...|                    |                 61|Univ Tenaga Nas, ...|Univ Tenaga Nas, ...|             |           2021|           2021|    15|    1|      null|      null|        null|           null|      126|    141|           16|         GENEVA|WORLD TRADE CENTE...|INDERSCIENCE ENTE...|PERCEIVED POLITIC...|              |                 |              |           null|           Article|                null|                null|                null|                null|dianahanafii@gmai...|Managing sustaina...|INTERNATIONAL JOU...| INT J INNOV SUSTAIN|Int. J. Innov. Su...|1740-8822|                null|1740-8830|null|    null|                  |                    |
# |WOS:000545569800012|We design a distr...|This work was sup...|                 22|Delft Univ Techno...|Delft Univ Techno...|             |           2021|       APR 2021|     5|    2|      null|      null|        null|           null|      499|    504|            6|     PISCATAWAY|445 HOES LANE, PI...|IEEE-INST ELECTRI...|   AGGREGATIVE GAMES|              |                 |              |           null|           Article|                   1|0000-0002-5261-67...|   Bianchi, Mattia 1|   Bianchi, Mattia 1|m.bianchi@tudelft...|Fully Distributed...|IEEE CONTROL SYST...|IEEE CONTR SYST LETT|IEEE Control Syst...|2475-1456|10.1109/LCSYS.202...|     null|null|    null|                  |Netherlands Organ...|
# |WOS:000551367300002|Averaging methods...|                    |                 16|Alexandria Univ, ...|Alexandria Univ, ...|             |           2021|           2021|    22|    1|      null|      null|        null|           null|        9|     15|            7|     MAZANDARAN|JOURNAL MATHEMATI...|JOURNAL MATHEMATI...|                    |              |                 |              |           null|           Article|                null|                null|                null|                null|hamedk66@sci.dmu....|A parabolic trans...|JOURNAL OF MATHEM...|J MATH COMPUT SCI-JM|J. Math. Comput. ...|2008-949X|10.22436/jmcs.022...|     null|null|    null|                  |                    |
# |WOS:000570974900019|Cancer is a multi...|Research funded b...|                 53|Spiru Haret Univ,...|Univ Bucharest, F...|             |           2021|    FEB 15 2021|    11|    1|      null|      null|        null|           null|     7543|   7557|           15|      BUCURESTI|BIOINTERFACE RESE...|BIOINTERFACE RESE...|BREAST-CANCER, S-...|              |                 |              |           null|           Article|G-2148-2014 2| H-...|0000-0003-0596-93...|Albu, Camelia 3| ...|Albu, Camelia 3| ...|1| 10| 2 3| 6 9| ...|Canine Model For ...|BIOINTERFACE RESE...|BIOINTERFACE RES APP|Biointerface Res....|2069-5837|10.33263/BRIAC111...|     null|null|    null|                  |                    |
# |WOS:000577180200001|The purpose of th...|                    |                 23|Univ Estado Rio d...|Univ Estado Rio d...|             |           2021|           2021|  null|   39|      null|      null|        null|           null|      429|    433|            5|         MURCIA|C CABO VIDIO 27, ...|FEDERACION ESPANO...|            FOOTBALL|              |                 |              |           null|           Article|                null|                null|                null|                null|2| 5| julianabran...|Epidemiology of i...|RETOS-NUEVAS TEND...|RETOS-NUEV TEND EDUC|               Retos|1579-1726|                null|1988-2041|null|    null|                  |                    |
# +-------------------+--------------------+--------------------+-------------------+--------------------+--------------------+-------------+---------------+---------------+------+-----+----------+----------+------------+---------------+---------+-------+-------------+---------------+--------------------+--------------------+--------------------+--------------+-----------------+--------------+---------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+---------+----+--------+------------------+--------------------+
# only showing top 25 rows

# %%
# %%time

wosOutput.coalesce(16).write.option("header","True") \
                               .option("sep","\t") \
                               .option("quoteAll", False) \
                               .option("emptyValue", None) \
                               .option("nullValue", None)\
                               .mode("overwrite") \
                               .csv('/WoSraw_2020/nodes')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed eval> in <module>
#
# AttributeError: 'function' object has no attribute 'option'

# %%
wosOutput.write.format('csv').option('header', True).mode('overwrite').option('sep', '\t').save('/WoSraw_2020/nodes')

# %%
# Out:
# 1587

# %%
# Out:
# 1587
